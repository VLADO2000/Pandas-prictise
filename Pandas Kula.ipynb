# %%
import pandas as pd

# %%
data_dict = {
    "Name":["Harry", "Fred", "Alice", "George", "Kate","Angeline", "Ivan"],
    "Score":[150, 0, 20, 0, 20, 30, 0],
    "Status":["seaker", "beater", "chaser", "beater", "chesar", "chesar", "keeper"]
}

# %%
df = pd.DataFrame(data_dict)
df
# Out:
#        Name  Score  Status
# 0     Harry    150  seaker
# 1      Fred      0  beater
# 2     Alice     20  chaser
# 3    George      0  beater
# 4      Kate     20  chesar
# 5  Angeline     30  chesar
# 6      Ivan      0  keeper

# %%
listt = [
    ["Harry", "Fred", "Alice", "George", "Kate","Angeline", "Ivan"],
    [150, 0, 20, 0, 20, 30, 0],
    ["seaker", "beater", "chaser", "beater", "chesar", "chesar", "keeper"]
]
df= pd.DataFrame(listt).T
df
# Out:
#           0    1       2
# 0     Harry  150  seaker
# 1      Fred    0  beater
# 2     Alice   20  chaser
# 3    George    0  beater
# 4      Kate   20  chesar
# 5  Angeline   30  chesar
# 6      Ivan    0  keeper

# %%
df
# Out:
#           0    1       2
# 0     Harry  150  seaker
# 1      Fred    0  beater
# 2     Alice   20  chaser
# 3    George    0  beater
# 4      Kate   20  chesar
# 5  Angeline   30  chesar
# 6      Ivan    0  keeper

# %%
df= df.rename(columns={0:"Name", 1:"Score", 2:"Status"})
df
# Out:
#        Name Score  Status
# 0     Harry   150  seaker
# 1      Fred     0  beater
# 2     Alice    20  chaser
# 3    George     0  beater
# 4      Kate    20  chesar
# 5  Angeline    30  chesar
# 6      Ivan     0  keeper

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/sharkeee/Python/Pandas from Kulazenko'

# %%
os.listdir()
# Out:
# ['Pandas Kula.ipynb', '.ipynb_checkpoints']

# %%
f1 = open("file.doc", "w")
f1.close
f2 = open("file.doc", "w")
print("Hello", file = f2)
print("world", file = f2)
f2.close
# Out:
# <function TextIOWrapper.close()>

# %%
import pandas as pd

# %%
df_nf = pd.read_csv("netflix_titles.csv")
df_nf
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_nf.describe(include='all')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
pd.options.display.max_rows=10
df_nf
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_nf["title"]
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
df_nf["title"].count()
# Out:
# 8807

# %%
df_nf["type"].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df_nf["type"].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
df_nf.select_dtypes('int64')
# Out:
#       release_year
# 0             2020
# 1             2021
# 2             2021
# 3             2021
# 4             2021
# ...            ...
# 8802          2007
# 8803          2018
# 8804          2009
# 8805          2006
# 8806          2015
#
# [8807 rows x 1 columns]

# %%
pd.options.display.max_columns = 12
df_nf.select_dtypes(['int64', 'object'])
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
from matplotlib import pyplot as plt

# %%
df_nf[df_nf['release_year']>2010].hist(color='red')
# Out:
# array([[<AxesSubplot:title={'center':'release_year'}>]], dtype=object)

# %%
df_nf[(df_nf['release_year']>2010)&(df_nf['type']=='Movie')&(df_nf['country']=='United States')].hist(color='green')
# Out:
# array([[<AxesSubplot:title={'center':'release_year'}>]], dtype=object)

# %%
df_nf['country']=='United States'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802     True
# 8803    False
# 8804     True
# 8805     True
# 8806    False
# Name: country, Length: 8807, dtype: bool

# %%
no_horor = df_nf[~df_nf['listed_in'].str.contains('Horror')]

# %%
no_horor
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8801   s8802    Movie                Zinzana  Majid Al Ansari
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
new_list = df_nf['listed_in'].str.split(',', expand=True)

# %%
new_nt = df_nf.loc[:, df_nf.columns != 'listed_in']

# %%
new_df = pd.concat([new_nt, new_list], axis=1)

# %%
new_df
# Out:
#                              0                        1  \
# 0                Documentaries                     None
# 1       International TV Shows                TV Dramas
# 2               Crime TV Shows   International TV Shows
# 3                   Docuseries               Reality TV
# 4       International TV Shows        Romantic TV Shows
# ...                        ...                      ...
# 8802               Cult Movies                   Dramas
# 8803                  Kids' TV          Korean TV Shows
# 8804                  Comedies            Horror Movies
# 8805  Children & Family Movies                 Comedies
# 8806                    Dramas     International Movies
#
#                            2 show_id     type                  title  ...  \
# 0                       None      s1    Movie   Dick Johnson Is Dead  ...
# 1               TV Mysteries      s2  TV Show          Blood & Water  ...
# ...

# %%
new_list = new_list.rename(columns={0:"Main_Type", 1:"Add_Type", 2:"Add_Sec_Type"})

# %%
new_list
# Out:
#                      Main_Type                 Add_Type  \
# 0                Documentaries                     None
# 1       International TV Shows                TV Dramas
# 2               Crime TV Shows   International TV Shows
# 3                   Docuseries               Reality TV
# 4       International TV Shows        Romantic TV Shows
# ...                        ...                      ...
# 8802               Cult Movies                   Dramas
# 8803                  Kids' TV          Korean TV Shows
# 8804                  Comedies            Horror Movies
# 8805  Children & Family Movies                 Comedies
# 8806                    Dramas     International Movies
#
#                 Add_Sec_Type
# 0                       None
# 1               TV Mysteries
# 2      TV Action & Adventure
# 3                       None
# 4                TV Comedies
# ...                      ...
# 8802               Thrillers
# 8803             TV Comedies
# ...

# %%
new_df = pd.concat([new_nt, new_list],axis=1)

# %%
new_df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  ...  \
# 0                                                   NaN  United States  ...
# ...

# %%
new_df = new_df.rename(columns={"title":"titless"})
new_df
# Out:
#      show_id     type                titless         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  ...  \
# 0                                                   NaN  United States  ...
# ...

# %%
new_df[['type', 'director']]
# Out:
#          type         director
# 0       Movie  Kirsten Johnson
# 1     TV Show              NaN
# 2     TV Show  Julien Leclercq
# 3     TV Show              NaN
# 4     TV Show              NaN
# ...       ...              ...
# 8802    Movie    David Fincher
# 8803  TV Show              NaN
# 8804    Movie  Ruben Fleischer
# 8805    Movie     Peter Hewitt
# 8806    Movie      Mozez Singh
#
# [8807 rows x 2 columns]

# %%
new_df.loc[0:20,'type':'duration']
# Out:
#        type                                            titless  \
# 0     Movie                               Dick Johnson Is Dead
# 1   TV Show                                      Blood & Water
# 2   TV Show                                          Ganglands
# 3   TV Show                              Jailbirds New Orleans
# 4   TV Show                                       Kota Factory
# ..      ...                                                ...
# 16    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17  TV Show                                    Falsa identidad
# 18    Movie                                          Intrusion
# 19  TV Show                                             Jaguar
# 20  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
#
#                                          director  \
# 0                                 Kirsten Johnson
# 1                                             NaN
# 2                                 Julien Leclercq
# ...

# %%
df_nf
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_nf.rename(columns={'listed_in':'category'}, inplace=True)

# %%
df_nf.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'category', 'description'],
#       dtype='object')

# %%
new_df['rating']
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
ct = pd.read_csv('covid_traffic.csv')

# %%
pd.options.display.max_columns = None
ct
# Out:
#      AggregationMethod        Date  Version                    AirportName  \
# 0                Daily  2020-04-03      1.0                Kingsford Smith
# 1                Daily  2020-04-13      1.0                Kingsford Smith
# 2                Daily  2020-07-10      1.0                Kingsford Smith
# 3                Daily  2020-09-02      1.0                Kingsford Smith
# 4                Daily  2020-10-31      1.0                Kingsford Smith
# ...                ...         ...      ...                            ...
# 7242             Daily  2020-06-05      1.0  Seattle-Tacoma International
# 7243             Daily  2020-10-03      1.0  Seattle-Tacoma International
# 7244             Daily  2020-07-16      1.0  Seattle-Tacoma International
# 7245             Daily  2020-07-31      1.0  Seattle-Tacoma International
# 7246             Daily  2020-08-30      1.0  Seattle-Tacoma International
#
# ...

# %%
ct['daily_flies'] = 1
ct
# Out:
#      AggregationMethod        Date  Version                    AirportName  \
# 0                Daily  2020-04-03      1.0                Kingsford Smith
# 1                Daily  2020-04-13      1.0                Kingsford Smith
# 2                Daily  2020-07-10      1.0                Kingsford Smith
# 3                Daily  2020-09-02      1.0                Kingsford Smith
# 4                Daily  2020-10-31      1.0                Kingsford Smith
# ...                ...         ...      ...                            ...
# 7242             Daily  2020-06-05      1.0  Seattle-Tacoma International
# 7243             Daily  2020-10-03      1.0  Seattle-Tacoma International
# 7244             Daily  2020-07-16      1.0  Seattle-Tacoma International
# 7245             Daily  2020-07-31      1.0  Seattle-Tacoma International
# 7246             Daily  2020-08-30      1.0  Seattle-Tacoma International
#
# ...

# %%
ct.columns
# Out:
# Index(['AggregationMethod', 'Date', 'Version', 'AirportName',
#        'PercentOfBaseline', 'Centroid', 'City', 'State', 'ISO_3166_2',
#        'Country', 'Geography', 'daily_flies'],
#       dtype='object')

# %%
cols = ['daily_flies','AggregationMethod', 'Date', 'Version', 'AirportName',
       'PercentOfBaseline', 'Centroid', 'City', 'State', 'ISO_3166_2',
       'Country', 'Geography']

# %%
ct = ct[cols]
ct
# Out:
#       daily_flies AggregationMethod        Date  Version  \
# 0               1             Daily  2020-04-03      1.0
# 1               1             Daily  2020-04-13      1.0
# 2               1             Daily  2020-07-10      1.0
# 3               1             Daily  2020-09-02      1.0
# 4               1             Daily  2020-10-31      1.0
# ...           ...               ...         ...      ...
# 7242            1             Daily  2020-06-05      1.0
# 7243            1             Daily  2020-10-03      1.0
# 7244            1             Daily  2020-07-16      1.0
# 7245            1             Daily  2020-07-31      1.0
# 7246            1             Daily  2020-08-30      1.0
#
#                         AirportName  PercentOfBaseline  \
# 0                   Kingsford Smith                 64
# 1                   Kingsford Smith                 29
# 2                   Kingsford Smith                 54
# ...

# %%
def count_baseline(x):
    if x<30:
        resul = 'low'
    elif 30<x<60:
        resul= 'middle'
    else:
        resul='high'
    return resul

# %%
ct['PercentOfBaseline'] = ct['PercentOfBaseline'].apply(count_baseline)

# %%
ct
# Out:
#       daily_flies AggregationMethod        Date  Version  \
# 0               1             Daily  2020-04-03      1.0
# 1               1             Daily  2020-04-13      1.0
# 2               1             Daily  2020-07-10      1.0
# 3               1             Daily  2020-09-02      1.0
# 4               1             Daily  2020-10-31      1.0
# ...           ...               ...         ...      ...
# 7242            1             Daily  2020-06-05      1.0
# 7243            1             Daily  2020-10-03      1.0
# 7244            1             Daily  2020-07-16      1.0
# 7245            1             Daily  2020-07-31      1.0
# 7246            1             Daily  2020-08-30      1.0
#
#                         AirportName PercentOfBaseline  \
# 0                   Kingsford Smith              high
# 1                   Kingsford Smith               low
# 2                   Kingsford Smith            middle
# 3                   Kingsford Smith               low
# ...

# %%
ct['AirportName'].unique
# Out:
# <bound method Series.unique of 0                     Kingsford Smith
# 1                     Kingsford Smith
# 2                     Kingsford Smith
# 3                     Kingsford Smith
# 4                     Kingsford Smith
#                     ...
# 7242    Seattle-Tacoma International
# 7243    Seattle-Tacoma International
# 7244    Seattle-Tacoma International
# 7245    Seattle-Tacoma International
# 7246    Seattle-Tacoma International
# Name: AirportName, Length: 7247, dtype: object>

# %%
ct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7247 entries, 0 to 7246
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   daily_flies        7247 non-null   int64
#  1   AggregationMethod  7247 non-null   object
#  2   Date               7247 non-null   object
#  3   Version            7247 non-null   float64
#  4   AirportName        7247 non-null   object
#  5   PercentOfBaseline  7247 non-null   object
#  6   Centroid           7247 non-null   object
#  7   City               7247 non-null   object
#  8   State              7247 non-null   object
#  9   ISO_3166_2         7247 non-null   object
#  10  Country            7247 non-null   object
#  11  Geography          7247 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 679.5+ KB

# %%
df_nf
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_nf['type']=='Movie'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802     True
# 8803    False
# 8804     True
# 8805     True
# 8806     True
# Name: type, Length: 8807, dtype: bool

# %%
df_nf['type'] = df_nf['type']=='Movie'

# %%
df_nf
# Out:
#      show_id   type                  title         director  \
# 0         s1   True   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  False          Blood & Water              NaN
# 2         s3  False              Ganglands  Julien Leclercq
# 3         s4  False  Jailbirds New Orleans              NaN
# 4         s5  False           Kota Factory              NaN
# ...      ...    ...                    ...              ...
# 8802   s8803   True                 Zodiac    David Fincher
# 8803   s8804  False            Zombie Dumb              NaN
# 8804   s8805   True             Zombieland  Ruben Fleischer
# 8805   s8806   True                   Zoom     Peter Hewitt
# 8806   s8807   True                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_nf['type'] = df_nf['type'].astype(int)
df_nf
# Out:
#      show_id  type                  title         director  \
# 0         s1     1   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2     0          Blood & Water              NaN
# 2         s3     0              Ganglands  Julien Leclercq
# 3         s4     0  Jailbirds New Orleans              NaN
# 4         s5     0           Kota Factory              NaN
# ...      ...   ...                    ...              ...
# 8802   s8803     1                 Zodiac    David Fincher
# 8803   s8804     0            Zombie Dumb              NaN
# 8804   s8805     1             Zombieland  Ruben Fleischer
# 8805   s8806     1                   Zoom     Peter Hewitt
# 8806   s8807     1                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_nf.rename(columns={'type':'Movie_type'}, inplace=True)

# %%
df_nf
# Out:
#      show_id  Movie_type                  title         director  \
# 0         s1           1   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2           0          Blood & Water              NaN
# 2         s3           0              Ganglands  Julien Leclercq
# 3         s4           0  Jailbirds New Orleans              NaN
# 4         s5           0           Kota Factory              NaN
# ...      ...         ...                    ...              ...
# 8802   s8803           1                 Zodiac    David Fincher
# 8803   s8804           0            Zombie Dumb              NaN
# 8804   s8805           1             Zombieland  Ruben Fleischer
# 8805   s8806           1                   Zoom     Peter Hewitt
# 8806   s8807           1                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
list_t = [0,1,-1,2,-2,3,-3,4,-4]

# %%
list(filter(lambda x: x<0, list_t))
# Out:
# [-1, -2, -3, -4]

# %%
df_nf['USA'] = df_nf['country'].apply(lambda x: int(x=="United States"))

# %%
df_nf
# Out:
#      show_id  Movie_type                  title         director  \
# 0         s1           1   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2           0          Blood & Water              NaN
# 2         s3           0              Ganglands  Julien Leclercq
# 3         s4           0  Jailbirds New Orleans              NaN
# 4         s5           0           Kota Factory              NaN
# ...      ...         ...                    ...              ...
# 8802   s8803           1                 Zodiac    David Fincher
# 8803   s8804           0            Zombie Dumb              NaN
# 8804   s8805           1             Zombieland  Ruben Fleischer
# 8805   s8806           1                   Zoom     Peter Hewitt
# 8806   s8807           1                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
import pandas as pd

# %%
rdf = pd.read_csv('Independence100.csv')
rdf
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
# 99   100               Virgil's Real Barbecue  11391678.0             27
#
#           City   State  Meals Served
# 0     New York    N.Y.      469803.0
# ...

# %%
for x in rdf.groupby('State'):
    print(x)
# Out:
# ('Calif.',     Rank                     Restaurant       Sales  Average Check  \
# 33    34                  Bottega Louie  18521000.0             36
# 39    40        Original Joe's Westlake  18159612.0             35
# 46    47  Harris Ranch Inn & Restaurant  17599468.0             29
# 62    63                     China Live  15106280.0             54
# 70    71                    Cliff House  14465847.0             40
# 71    72               Castaway Burbank  14407413.0             60
# 78    79       Paradise Cove Beach Cafe  13654113.0             39
# 79    80                BOA Steakhouse   13552485.0            110
# 80    81                 Original Joe's  13177468.0             45
# 86    87                        Scoma's  12713394.0             65
# 94    95     Franciscan Crab Restaurant  12218147.0             59
# 95    96           George's at the Cove  12194000.0             80
#
#               City   State  Meals Served
# 33     Los Angeles  Calif.      322562.0
# ...

# %%
rdf.groupby('City').agg('mean')
# Out:
#                       Rank         Sales  Average Check   Meals Served
# City
# Amarillo         90.000000  1.250520e+07      24.000000  478000.000000
# Atlanta          56.000000  1.639438e+07      81.500000  221000.000000
# Atlantic City    76.000000  1.398784e+07      39.000000  129630.000000
# Austin           73.000000  1.438190e+07      29.000000  495927.000000
# Bal Harbour      39.000000  1.821691e+07      54.000000  256830.000000
# Boston           52.000000  1.706348e+07     106.000000  160762.000000
# Burbank          72.000000  1.440741e+07      60.000000  180320.000000
# Cape May         62.000000  1.545000e+07      43.000000  320000.000000
# Chicago          48.533333  1.789880e+07      85.066667  235565.466667
# Coalinga         47.000000  1.759947e+07      29.000000  611928.000000
# Daly City        40.000000  1.815961e+07      35.000000  473492.000000
# Denver           74.000000  1.436210e+07      37.000000  553378.000000
# ...

# %%
rdf.groupby('City').agg(['mean','median', 'count'])
# Out:
#                       Rank                      Sales                    \
#                       mean median count          mean      median count
# City
# Amarillo         90.000000   90.0     1  1.250520e+07  12505200.0     1
# Atlanta          56.000000   56.0     2  1.639438e+07  16394375.0     2
# Atlantic City    76.000000   76.0     1  1.398784e+07  13987843.0     1
# Austin           73.000000   73.0     1  1.438190e+07  14381904.0     1
# Bal Harbour      39.000000   39.0     1  1.821691e+07  18216906.0     1
# Boston           52.000000   52.0     1  1.706348e+07  17063477.0     1
# Burbank          72.000000   72.0     1  1.440741e+07  14407413.0     1
# Cape May         62.000000   62.0     1  1.545000e+07  15450000.0     1
# Chicago          48.533333   46.0    15  1.789880e+07  17637400.0    15
# Coalinga         47.000000   47.0     1  1.759947e+07  17599468.0     1
# Daly City        40.000000   40.0     1  1.815961e+07  18159612.0     1
# ...

# %%
df_count = rdf.groupby('City').agg({"Rank":['mean'], "Sales":["mean", "median"], "Average Check":["median"], "Meals Served":["median", "count"] })

# %%
df_count
# Out:
#                       Rank         Sales             Average Check  \
#                       mean          mean      median        median
# City
# Amarillo         90.000000  1.250520e+07  12505200.0          24.0
# Atlanta          56.000000  1.639438e+07  16394375.0          81.5
# Atlantic City    76.000000  1.398784e+07  13987843.0          39.0
# Austin           73.000000  1.438190e+07  14381904.0          29.0
# Bal Harbour      39.000000  1.821691e+07  18216906.0          54.0
# Boston           52.000000  1.706348e+07  17063477.0         106.0
# Burbank          72.000000  1.440741e+07  14407413.0          60.0
# Cape May         62.000000  1.545000e+07  15450000.0          43.0
# Chicago          48.533333  1.789880e+07  17637400.0          82.0
# Coalinga         47.000000  1.759947e+07  17599468.0          29.0
# Daly City        40.000000  1.815961e+07  18159612.0          35.0
# Denver           74.000000  1.436210e+07  14362103.0          37.0
# ...

# %%
df_count.columns
# Out:
# MultiIndex([(         'Rank',   'mean'),
#             (        'Sales',   'mean'),
#             (        'Sales', 'median'),
#             ('Average Check', 'median'),
#             ( 'Meals Served', 'median'),
#             ( 'Meals Served',  'count')],
#            )

# %%
df_count.index
# Out:
# Index(['Amarillo', 'Atlanta', 'Atlantic City', 'Austin', 'Bal Harbour',
#        'Boston', 'Burbank', 'Cape May', 'Chicago', 'Coalinga', 'Daly City',
#        'Denver', 'Fort Lauderdale', 'Frankenmuth', 'Ft. Lauderdale', 'Houston',
#        'Indianapolis', 'La Jolla', 'Las Vegas', 'Los Angeles', 'Malibu',
#        'McLean', 'Miami', 'Miami Beach', 'Nashville', 'New York', 'Oak Brook',
#        'Orlando ', 'Philadelphia', 'Portland', 'Raleigh', 'Rosemont',
#        'San Francisco', 'Washington', 'West Hollywood', 'Wheeling'],
#       dtype='object', name='City')

# %%
df_count.loc["Boston", :]
# Out:
# Rank           mean            52.0
# Sales          mean      17063477.0
#                median    17063477.0
# Average Check  median         106.0
# Meals Served   median      160762.0
#                count            1.0
# Name: Boston, dtype: float64

# %%
df_count.loc["Boston", "Sales"]['median']
# Out:
# 17063477.0

# %% [raw]
# rdf

# %%
rdf
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
# 99   100               Virgil's Real Barbecue  11391678.0             27
#
#           City   State  Meals Served
# 0     New York    N.Y.      469803.0
# ...

# %%
rdf['top10'] = rdf['Rank'].apply(lambda x:'Yes'if x<10 else 'No')

# %%
rdf
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
# 99   100               Virgil's Real Barbecue  11391678.0             27
#
#           City   State  Meals Served top10
# 0     New York    N.Y.      469803.0   Yes
# ...

# %%
rdf.xs('Yes', level ='top10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_x/y7p2294s4t722sptmn184bvw0000gn/T/ipykernel_2191/3882780478.py in <module>
# ----> 1 rdf.xs('Yes', level ='top10')
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3745         if level is not None:
#    3746             if not isinstance(labels, MultiIndex):
# -> 3747                 raise TypeError("Index must be a MultiIndex")
#    3748             loc, new_ax = labels.get_loc_level(key, level=level, drop_level=drop_level)
#    3749
#
# TypeError: Index must be a MultiIndex

# %%
import pandas as pd

# %%
df = pd.read_csv('dirtydata.csv')
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df = df.dropna()
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
nf = pd.read_csv('dirtydata.csv')
nf
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
nf['Calories'].fillna(130, inplace=True)

# %%
nf
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
nf['Date'].fillna('2020/12/22', inplace=True)

# %%
nf
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
x = df['Calories'].mean()
x
# Out:
# 305.46206896551723

# %%
x = df['Calories'].median()
x
# Out:
# 300.0

# %%
x = df['Calories'].mode()[0]
x
# Out:
# 300.0

# %%
df = pd.read_csv('dirtydata.csv')

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df.dropna(subset=['Date'], inplace=True)

# %%
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df.loc[7, 'Duration'] = 45

# %%
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
for x in df.index:
    if df.loc[x,'Maxpulse'] >130:
        df.loc[x,'Maxpulse']=130

# %%
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         50 2020-12-01    110       130     409.1
# 1         50 2020-12-02    117       130     479.0
# 2         50 2020-12-03    103       130     340.0
# 3         45 2020-12-04    109       130     282.4
# 4         45 2020-12-05    117       130     406.0
# 5         50 2020-12-06    102       127     300.0
# 6         50 2020-12-07    110       130     374.0
# 7         45 2020-12-08    104       130     253.3
# 8         30 2020-12-09    109       130     195.1
# 9         50 2020-12-10     98       124     269.0
# 10        50 2020-12-11    103       130     329.3
# 11        50 2020-12-12    100       120     250.7
# 12        50 2020-12-12    100       120     250.7
# 13        50 2020-12-13    106       128     345.3
# 14        50 2020-12-14    104       130     379.3
# 15        50 2020-12-15     98       123     275.0
# 16        50 2020-12-16     98       120     215.2
# ...

# %%
for x in df.index:
    if df.loc[x,'Maxpulse']>129:
        df.loc[x,'Maxpulse']=150

# %%
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         50 2020-12-01    110       150     409.1
# 1         50 2020-12-02    117       150     479.0
# 2         50 2020-12-03    103       150     340.0
# 3         45 2020-12-04    109       150     282.4
# 4         45 2020-12-05    117       150     406.0
# 5         50 2020-12-06    102       150     300.0
# 6         50 2020-12-07    110       150     374.0
# 7         45 2020-12-08    104       150     253.3
# 8         30 2020-12-09    109       150     195.1
# 9         50 2020-12-10     98       150     269.0
# 10        50 2020-12-11    103       150     329.3
# 11        50 2020-12-12    100       120     250.7
# 12        50 2020-12-12    100       120     250.7
# 13        50 2020-12-13    106       150     345.3
# 14        50 2020-12-14    104       150     379.3
# 15        50 2020-12-15     98       150     275.0
# 16        50 2020-12-16     98       120     215.2
# ...

# %%
for x in df.index:
    if df.loc[x,'Maxpulse']>=150:
        df.drop(x, inplace=True)

# %%
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 11        50 2020-12-12    100       120     250.7
# 12        50 2020-12-12    100       120     250.7
# 16        50 2020-12-16     98       120     215.2
# 17        50 2020-12-17    100       120     300.0
# 18        45 2020-12-18     90       112       NaN
# 23        50 2020-12-23    130       101     300.0
# 26        50 2020-12-26    100       120     250.0
# 27        50 2020-12-27     92       118     241.0
# 31        50 2020-12-31     92       115     243.0

# %%
df.duplicated()
# Out:
# 11    False
# 12     True
# 16    False
# 17    False
# 18    False
# 23    False
# 26    False
# 27    False
# 31    False
# dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 11        50 2020-12-12    100       120     250.7
# 16        50 2020-12-16     98       120     215.2
# 17        50 2020-12-17    100       120     300.0
# 18        45 2020-12-18     90       112       NaN
# 23        50 2020-12-23    130       101     300.0
# 26        50 2020-12-26    100       120     250.0
# 27        50 2020-12-27     92       118     241.0
# 31        50 2020-12-31     92       115     243.0

# %%
dff = pd.read_csv('data.csv')
dff
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
dff.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000
